# %% [markdown]
# ## Rhesa simbolon
# ## 2109106105 ##

# %% [markdown]
# 1. Gunakan minimal 4 tipe visualiasi data.
# 2. Wajib menggunakan pie chart dan heatmap.
# 3. Kesimpulan dari visualisasi data dituliskan menggunakan cell  Markdown.
# 4. Gunakan title, xlabel, dan ylabel pada setiap visualisasi.
# 5. Semakin informatif visualisasi, semakin tinggi nilai posttest.

# %% [markdown]
# ## Import Library ##

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Melihat Data Yang Cocok ##

# %%
pd.read_csv('smoking.csv')
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 0              1    Male   38       Divorced      No Qualification
# 1              2  Female   42         Single      No Qualification
# 2              3    Male   40        Married                Degree
# 3              4  Female   40        Married                Degree
# 4              5  Female   39        Married          GCSE/O Level
# ...          ...     ...  ...            ...                   ...
# 1686        1687    Male   22         Single      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1688        1689    Male   45        Married      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
# 1690        1691    Male   31        Married                Degree
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 0        British     White    2,600 to 5,200  The North    No           NaN
# ...

# %%
smoke = pd.read_csv('smoking.csv')

# %%
smoke.drop(['Unnamed: 0'], axis=1)
data = smoke.groupby('marital_status').mean()
data
# Out:
#                 Unnamed: 0        age  amt_weekends  amt_weekdays
# marital_status
# Divorced        879.962733  51.608696     17.758621     14.586207
# Married         825.529557  51.538177     16.146853     14.265734
# Separated       860.161765  45.823529     15.590909     13.681818
# Single          880.707260  34.182670     16.139241     12.367089
# Widowed         825.242152  73.556054     16.925000     16.200000

# %% [markdown]
# ## Presentase perkawinan perokok dan non perokok ##

# %%
data = smoke[smoke['smoke'] == 'Yes']['marital_status'].value_counts()
plt.pie(data, labels=data.index, autopct="%1.1f%%",  startangle=90)
plt.title('data status perkawinan perokok ')
plt.show()

# %%
data = smoke[smoke['smoke'] == 'No']['marital_status'].value_counts()

plt.pie(data, labels=data.index, autopct="%1.1f%%",  startangle=90)
plt.title('data status perkawinan bukan perokok ')
plt.show()

# %% [markdown]
# ## kolerasi table ##

# %%
cor_matrix = smoke.iloc[0:, 1:].corr()

sns.heatmap(cor_matrix, cmap='coolwarm', annot=True, center=0)
plt.show()

# %% [markdown]
# ## Skala umur dan jumlah orang yang perokok ##

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
plt.hist(smoke['age'], bins=25, color='skyblue')
plt.title('Histogram Umur')
plt.ylabel('Frekuensi umur')
plt.xticks(rotation=0)

plt.xlabel('Umur')

plt.show()

# %%
data_na = smoke.groupby('nationality').mean()
data_na
# Out:
#               Unnamed: 0        age  amt_weekends  amt_weekdays
# nationality
# British       794.429368  47.382900     14.968992     12.480620
# English       734.447779  51.953181     16.846535     13.945545
# Irish        1036.695652  52.565217     19.545455     17.000000
# Other         821.521127  40.098592     13.857143     11.000000
# Refused       732.117647  52.705882     12.000000     12.000000
# Scottish     1456.443662  49.950704     18.666667     15.644444
# Unknown       657.000000  54.000000     20.000000     20.000000
# Welsh        1353.000000  51.590909     16.875000     16.312500

# %% [markdown]
# ## perbandingan gender pada perokok umum ##

# %%
smoke['gender'].value_counts()
plt.figure(figsize=(15,5))
plt.barh(dfBookingStatus.index, dfBookingStatus.values, color=['blue', 'red'])
plt.xlabel('jumlah orang')
plt.ylabel('gender')
plt.title('Perbandingan perokok menurut gender')
plt.show()
