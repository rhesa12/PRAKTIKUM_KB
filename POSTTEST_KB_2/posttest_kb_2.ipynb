# %% [markdown]
# ## rhesa simbolon nim: 2109106105 ##

# %%
import pandas as pd

# %%
pd.read_csv('smoking.csv')
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 0              1    Male   38       Divorced      No Qualification
# 1              2  Female   42         Single      No Qualification
# 2              3    Male   40        Married                Degree
# 3              4  Female   40        Married                Degree
# 4              5  Female   39        Married          GCSE/O Level
# ...          ...     ...  ...            ...                   ...
# 1686        1687    Male   22         Single      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1688        1689    Male   45        Married      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
# 1690        1691    Male   31        Married                Degree
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 0        British     White    2,600 to 5,200  The North    No           NaN
# ...

# %%
dataframe = pd.read_csv('smoking.csv')

# %%
dataframe[dataframe['ethnicity'] == 'Black']
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 73            74    Male   76        Married      No Qualification
# 292          293    Male   72        Married      Other/Sub Degree
# 584          585    Male   71        Married      Other/Sub Degree
# 714          715  Female   65         Single              A Levels
# 716          717    Male   72        Married      No Qualification
# 717          718  Female   29        Married                Degree
# 780          781    Male   43        Married                Degree
# 838          839    Male   27         Single                Degree
# 874          875  Female   30         Single                Degree
# 881          882    Male   43        Married          GCSE/O Level
# 901          902  Female   45         Single      No Qualification
# 910          911  Female   21         Single          GCSE/O Level
# 923          924  Female   29         Single          GCSE/O Level
# ...

# %% [markdown]
# ## 1. Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka. ##

# %%
dataframe.describe()
# Out:
#         Unnamed: 0          age  amt_weekends  amt_weekdays
# count  1691.000000  1691.000000    421.000000    421.000000
# mean    846.000000    49.836192     16.410926     13.750594
# std     488.293969    18.736851      9.892988      9.388292
# min       1.000000    16.000000      0.000000      0.000000
# 25%     423.500000    34.000000     10.000000      7.000000
# 50%     846.000000    48.000000     15.000000     12.000000
# 75%    1268.500000    65.500000     20.000000     20.000000
# max    1691.000000    97.000000     60.000000     55.000000

# %% [markdown]
# ## 2. Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka. ##

# %%
dataframe.select_dtypes(include=['number']).head(10)
# Out:
#    Unnamed: 0  age  amt_weekends  amt_weekdays
# 0           1   38           NaN           NaN
# 1           2   42          12.0          12.0
# 2           3   40           NaN           NaN
# 3           4   40           NaN           NaN
# 4           5   39           NaN           NaN
# 5           6   37           NaN           NaN
# 6           7   53           6.0           6.0
# 7           8   44           NaN           NaN
# 8           9   40           8.0           8.0
# 9          10   41          15.0          12.0

# %% [markdown]
# ## 3. Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin. ##

# %%
informasi = {
    "Jumlah Record": len(dataframe),
    "Jumlah Atribut": len(dataframe.columns),
    "Jumlah Atribut dengan Tipe Angka": len(dataframe.select_dtypes(include=['number']).columns),
    "Nama Atribut": list(dataframe.columns)
}

# %%
for i, j in informasi.items():
    print (i, end = " : ")
    if type(j) == list:
        print('')
        for k in range(len(j)):
            print(k+1, j[k])
    else:
        print(j)
# Out:
# Jumlah Record : 1691
# Jumlah Atribut : 13
# Jumlah Atribut dengan Tipe Angka : 4
# Nama Atribut :
# 1 Unnamed: 0
# 2 gender
# 3 age
# 4 marital_status
# 5 highest_qualification
# 6 nationality
# 7 ethnicity
# 8 gross_income
# 9 region
# 10 smoke
# 11 amt_weekends
# 12 amt_weekdays
# 13 type

# %% [markdown]
# ## 4. Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice. ##

# %%
dataframe.iloc[105:, 3:]
# Out:
#      marital_status highest_qualification nationality ethnicity  \
# 105         Married                Degree     English     White
# 106       Separated      No Qualification       Welsh     White
# 107         Married     Higher/Sub Degree     English     White
# 108         Married                Degree     English     White
# 109         Married      No Qualification     English     White
# ...             ...                   ...         ...       ...
# 1686         Single      No Qualification    Scottish     White
# 1687       Divorced      Other/Sub Degree     English     White
# 1688        Married      Other/Sub Degree    Scottish     White
# 1689        Married      No Qualification     English     White
# 1690        Married                Degree    Scottish     White
#
#           gross_income     region smoke  amt_weekends  amt_weekdays  \
# 105   10,400 to 15,600  The North    No           NaN           NaN
# ...

# %%
dataframe.loc[105:, dataframe.columns[3:]]
# Out:
#      marital_status highest_qualification nationality ethnicity  \
# 105         Married                Degree     English     White
# 106       Separated      No Qualification       Welsh     White
# 107         Married     Higher/Sub Degree     English     White
# 108         Married                Degree     English     White
# 109         Married      No Qualification     English     White
# ...             ...                   ...         ...       ...
# 1686         Single      No Qualification    Scottish     White
# 1687       Divorced      Other/Sub Degree     English     White
# 1688        Married      Other/Sub Degree    Scottish     White
# 1689        Married      No Qualification     English     White
# 1690        Married                Degree    Scottish     White
#
#           gross_income     region smoke  amt_weekends  amt_weekdays  \
# 105   10,400 to 15,600  The North    No           NaN           NaN
# ...

# %% [markdown]
# ## 5. Tampilkan jumlah nilai dari semua attribute yang bernilai object (contoh : Jenis Kelamin, Agama). ##

# %%
nama_kolom = dataframe.columns.tolist()

# %%
for i in nama_kolom:
    print(dataframe[i].value_counts())
# Out:
# Female    965
# Male      726
# Name: gender, dtype: int64
# 40    43
# 34    40
# 31    38
# 42    37
# 33    36
#       ..
# 90     3
# 91     2
# 93     2
# 95     1
# 97     1
# Name: age, Length: 79, dtype: int64
# Married      812
# Single       427
# Widowed      223
# Divorced     161
# Separated     68
# Name: marital_status, dtype: int64
# No Qualification     586
# GCSE/O Level         308
# Degree               262
# Other/Sub Degree     127
# Higher/Sub Degree    125
# A Levels             105
# GCSE/CSE             102
# ONC/BTEC              76
# Name: highest_qualification, dtype: int64
# English     833
# British     538
# Scottish    142
# Other        71
# Welsh        66
# Irish        23
# Refused      17
# Unknown       1
# Name: nationality, dtype: int64
# White      1560
# Asian        41
# Black        34
# Chinese      27
# Mixed        14
# Refused      13
# Unknown       2
# Name: ethnicity, dtype: int64
# 5,200 to 10,400     396
# 10,400 to 15,600    268
# ...
